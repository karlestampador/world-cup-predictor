# %% [markdown]
# # FIFA World Cup 2026: Full Tournament Predictions
# By Karl Estampador :)
#
# Simulates all 104 matches using the Elo-based model from whatever model is selected.
# The higher-Elo team always advances.
# Third-place bracket allocation follows FIFA's official 495-combination lookup table.

# %%
# Load model functions and data
# %run ../models/ensemble_model.ipynb
# Out:
# Imports OK
#   USE_FORMER_NAMES_TABLE   = True
#   USE_REAL_NEUTRAL_FLAG    = False
#   INCLUDE_GOALS_REGRESSION = False
# WC matches 2002 - 2022: 384
# Matches per tournament:
# year
# 2002    64
# 2006    64
# 2010    64
# 2014    64
# 2018    64
# 2022    64
# Name: count, dtype: int64
#
# Shootout records in same period: 310
#
# train.csv rows: 192 | test.csv rows: 48
# Team names normalised: 6 cells remapped
#   China -> China PR: 3 cells
#   Serbia -> Serbia and Montenegro: 3 cells
#
# Sample rows (home):
#           date home_team         home_team_norm
# 11  2002-06-04     China               China PR
# 71  2006-06-11    Serbia  Serbia and Montenegro
#
# Sample rows (away):
#            date away_team         away_team_norm
# 23   2002-06-08     China               China PR
# 43   2002-06-13     China               China PR
# 84   2006-06-16    Serbia  Serbia and Montenegro
# 101  2006-06-21    Serbia  Serbia and Montenegro
#
# Rows before join: 384
# Rows dropped (team not in train.csv): 0
# Rows remaining: 384
# Class distribution (before feature drop):
#   home_win: 181 (47.1%)
#   draw: 67 (17.4%)
#   away_win: 136 (35.4%)
#
# Total training matches: 384
# Rows dropped for NaN features: 64
#   (squad_total_market_value_eur was not recorded for 2002 - all 64 matches from that year are excluded)
#
# Final training set shape: (320, 7)
# Class distribution (training set):
#   home_win: 151 (47.2%)
#   draw: 53 (16.6%)
#   away_win: 116 (36.2%)
#
# 5-fold stratified cross-validation results
#
# Logistic Regression alone
# =============================================
#   Accuracy : 0.578  +/-0.044
#   Log-loss : 0.941  +/-0.047
#
# LightGBM alone
# =============================================
#   Accuracy : 0.494  +/-0.041
#   Log-loss : 1.382  +/-0.194
#
# Ensemble (equal weights 50/50)
# =============================================
#   Accuracy : 0.547  +/-0.033
#   Log-loss : 1.011  +/-0.070
# Blend weight search (minimise CV log-loss)
# Fixed LightGBM weight = 1.0; searching Logistic Regression weight.
# =======================================================
# Best weights: LR=2.00, LGBM=1.00
#   Implied blend: 67% Logistic Regression / 33% LightGBM
#   CV accuracy : 0.584
#   CV log-loss : 0.973
#
# Top 5 weight settings by log-loss:
#   w_lr   LR %   LGBM %   Accuracy   Log-loss
# ----------------------------------------------
#   2.00     67       33      0.584      0.973
#   1.95     66       34      0.581      0.974
#   1.90     66       34      0.581      0.975
#   1.85     65       35      0.578      0.976
#   1.80     64       36      0.578      0.978
#
# Model comparison (CV means)
# ----------------------------------------------------------
# Model                              Accuracy   Log-loss
# ----------------------------------------------------------
# Logistic Regression                   0.578      0.941
# LightGBM                              0.494      1.382
# Ensemble (50/50)                      0.547      1.011
# Ensemble (tuned 67/33)                0.584      0.973
#
# Note: random-guess baseline accuracy for 3 classes: 0.33
# Training set size: 320 matches
# Class order: ['away_win', 'draw', 'home_win']
# Model agreement (out-of-fold CV predictions)
# =============================================
#   Same predicted class : 68.4%
#   Disagreement rate    : 31.6%
#
# Top 5 disagreements (largest confidence gap):
#
# 2022-11-22  Mexico vs Poland
#   Logistic Regression: Home Win (45%)
#   LightGBM:            Away Win (96%)
#   Actual outcome:      Draw
#
# 2018-07-14  Belgium vs England
#   Logistic Regression: Home Win (47%)
#   LightGBM:            Away Win (95%)
#   Actual outcome:      Home Win
#
# 2022-11-27  Spain vs Germany
#   Logistic Regression: Away Win (42%)
#   LightGBM:            Home Win (89%)
#   Actual outcome:      Draw
#
# 2014-06-24  Italy vs Uruguay
#   Logistic Regression: Home Win (46%)
#   LightGBM:            Away Win (92%)
#   Actual outcome:      Away Win
#
# 2010-06-26  United States vs Ghana
#   Logistic Regression: Home Win (49%)
#   LightGBM:            Away Win (94%)
#   Actual outcome:      Away Win
# Chart saved to outputs\ensemble_feature_importance.png
# ELO lookup ready (48 teams)
# Test features loaded for 55 name variants
# Ensemble prediction functions ready.
# predict_group_match, predict_knockout_winner, get_lr_proba - ready.
# predict_winner and predict_score aliased to ensemble versions.
# -- Group match (draws allowed) --
# Match                                Result   Winner/Draw            Proba (hw / d / aw)
# -------------------------------------------------------------------------------------
# Mexico vs South Africa               2-0     Mexico                 hw=0.72  d=0.14  aw=0.14
# South Korea vs Czechia               0-1     Czechia                hw=0.41  d=0.16  aw=0.43
# Canada vs Bosnia and Herzegovina     1-1     Draw                   hw=0.35  d=0.35  aw=0.30
# United States vs Paraguay            2-0     United States          hw=0.69  d=0.11  aw=0.20
#
# -- Knockout (no draws) --
# Match                                Winner                 Win Prob
# -----------------------------------------------------------------
# Mexico vs South Africa               Mexico                 0.834
# South Korea vs Czechia               Czechia                0.513
# Canada vs Bosnia and Herzegovina     Canada                 0.541
# United States vs Paraguay            United States          0.778
# Logistic regression alone: 57.8% accuracy, log-loss 0.941.
# LightGBM alone: 49.4% accuracy, log-loss 1.382.
# Ensemble (50/50): 54.7% accuracy, log-loss 1.011.
# Ensemble (tuned weights): 58.4% accuracy, log-loss 0.973.
# Best blend: 67% LR / 33% LightGBM.
# The tuned ensemble improved on accuracy but only matched the better single model on the other metric. Weight tuning did help versus the 50/50 blend (log-loss 1.011 -> 0.973).

# %%
import pandas as pd
from pathlib import Path

DATA = Path('data')

# Load schedule and team registry
matches_df = pd.read_csv(DATA / 'matches.csv')
teams_df   = pd.read_csv(DATA / 'teams.csv')

# Build team-ID -> name lookup
id_to_name: dict[int, str] = dict(zip(teams_df['id'], teams_df['team_name']))
name_to_group: dict[str, str] = dict(zip(teams_df['team_name'], teams_df['group_letter']))

alloc_df = pd.read_csv(DATA / 'third_place_allocation.csv')

print(f'{len(matches_df)} matches loaded | {len(teams_df)} teams | allocation table: {len(alloc_df)} rows')
# Out:
# 104 matches loaded | 48 teams | allocation table: 495 rows

# %% [markdown]
# ---
# ## 1. Group Stage Simulation

# %%
group_matches = matches_df[matches_df['stage_id'] == 1].copy()

gs_results = []   # list of dicts, one per group-stage match

for _, row in group_matches.iterrows():
    home = id_to_name[int(row['home_team_id'])]
    away = id_to_name[int(row['away_team_id'])]
    hg, ag, winner = predict_group_match(home, away)
    gs_results.append({
        'match':      int(row['match_number']),
        'group':      row['match_label'],
        'home':       home,
        'away':       away,
        'home_goals': hg,
        'away_goals': ag,
        'winner':     winner if winner else 'Draw',
    })

gs_df = pd.DataFrame(gs_results)
print(f'{len(gs_df)} group-stage matches simulated')
# Out:
# 72 group-stage matches simulated

# %% [markdown]
# ### Group Stage Results

# %%
display_gs = gs_df[['match','group','home','home_goals','away_goals','away','winner']].copy()
display_gs.columns = ['Match','Group','Home','HG','AG','Away','Winner']

pd.set_option('display.max_rows', 80)
pd.set_option('display.width', 120)
pd.set_option('display.max_colwidth', 30)

display_gs
# Out:
#     Match    Group                    Home  HG  AG                    Away                  Winner
# 0       1  Group A                  Mexico   2   0            South Africa                  Mexico
# 1       2  Group A             South Korea   0   1                 Czechia                 Czechia
# 2       3  Group B                  Canada   1   1  Bosnia and Herzegovina                    Draw
# 3       4  Group D                     USA   2   0                Paraguay                     USA
# 4       5  Group B                   Qatar   0   2             Switzerland             Switzerland
# 5       6  Group C                  Brazil   0   1                 Morocco                 Morocco
# 6       7  Group C                   Haiti   0   2                Scotland                Scotland
# 7       8  Group D               Australia   0   2                  Turkey                  Turkey
# 8       9  Group E                 Germany   2   0                 Curaçao                 Germany
# 9      10  Group F             Netherlands   2   0                   Japan             Netherlands
# 10     11  Group E           Côte d'Ivoire   0   1                 Ecuador                 Ecuador
# 11     12  Group F                  Sweden   2   0                 Tunisia                  Sweden
# 12     13  Group H                   Spain   2   0              Cabo Verde                   Spain
# 13     14  Group G                 Belgium   1   0                   Egypt                 Belgium
# 14     15  Group H            Saudi Arabia   0   2                 Uruguay                 Uruguay
# 15     16  Group G                 IR Iran   2   0             New Zealand                 IR Iran
# 16     17  Group I                  France   2   0                 Senegal                  France
# 17     18  Group I                    Iraq   0   2                  Norway                  Norway
# 18     19  Group J               Argentina   2   0                 Algeria               Argentina
# 19     20  Group J                 Austria   2   0                  Jordan                 Austria
# 20     21  Group K                Portugal   2   0                DR Congo                Portugal
# 21     22  Group L                 England   2   0                 Croatia                 England
# 22     23  Group L                   Ghana   2   0                  Panama                   Ghana
# 23     24  Group K              Uzbekistan   0   2                Colombia                Colombia
# 24     25  Group A                 Czechia   1   0            South Africa                 Czechia
# 25     26  Group B             Switzerland   2   0  Bosnia and Herzegovina             Switzerland
# 26     27  Group B                  Canada   2   0                   Qatar                  Canada
# 27     28  Group A                  Mexico   0   1             South Korea             South Korea
# 28     29  Group D                     USA   2   0               Australia                     USA
# 29     30  Group C                Scotland   0   2                 Morocco                 Morocco
# 30     31  Group C                  Brazil   2   0                   Haiti                  Brazil
# 31     32  Group D                  Turkey   2   0                Paraguay                  Turkey
# 32     33  Group F             Netherlands   2   0                  Sweden             Netherlands
# 33     34  Group E                 Germany   2   0           Côte d'Ivoire                 Germany
# 34     35  Group E                 Ecuador   2   0                 Curaçao                 Ecuador
# 35     36  Group F                 Tunisia   0   2                   Japan                   Japan
# 36     37  Group H                   Spain   2   0            Saudi Arabia                   Spain
# 37     38  Group G                 Belgium   2   0                 IR Iran                 Belgium
# 38     39  Group H                 Uruguay   2   0              Cabo Verde                 Uruguay
# 39     40  Group G             New Zealand   0   2                   Egypt                   Egypt
# 40     41  Group J               Argentina   2   0                 Austria               Argentina
# 41     42  Group I                  France   2   0                    Iraq                  France
# 42     43  Group I                  Norway   0   1                 Senegal                 Senegal
# 43     44  Group J                  Jordan   0   2                 Algeria                 Algeria
# 44     45  Group K                Portugal   2   0              Uzbekistan                Portugal
# 45     46  Group L                 England   1   0                   Ghana                 England
# 46     47  Group L                  Panama   0   2                 Croatia                 Croatia
# 47     48  Group K                Colombia   2   0                DR Congo                Colombia
# 48     49  Group B             Switzerland   2   0                  Canada             Switzerland
# 49     50  Group B  Bosnia and Herzegovina   2   0                   Qatar  Bosnia and Herzegovina
# 50     51  Group C                Scotland   0   2                  Brazil                  Brazil
# 51     52  Group C                 Morocco   2   0                   Haiti                 Morocco
# 52     53  Group A                 Czechia   0   1                  Mexico                  Mexico
# 53     54  Group A            South Africa   0   2             South Korea             South Korea
# 54     55  Group E                 Curaçao   0   2           Côte d'Ivoire           Côte d'Ivoire
# 55     56  Group E                 Ecuador   0   2                 Germany                 Germany
# 56     57  Group F                   Japan   0   2                  Sweden                  Sweden
# 57     58  Group F                 Tunisia   0   2             Netherlands             Netherlands
# 58     59  Group D                  Turkey   1   0                     USA                  Turkey
# 59     60  Group D                Paraguay   2   0               Australia                Paraguay
# 60     61  Group I                  Norway   0   2                  France                  France
# 61     62  Group I                 Senegal   2   0                    Iraq                 Senegal
# 62     63  Group H              Cabo Verde   1   0            Saudi Arabia              Cabo Verde
# 63     64  Group H                 Uruguay   0   2                   Spain                   Spain
# 64     65  Group G                   Egypt   2   0                 IR Iran                   Egypt
# 65     66  Group G             New Zealand   0   2                 Belgium                 Belgium
# 66     67  Group L                  Panama   0   2                 England                 England
# 67     68  Group L                 Croatia   2   0                   Ghana                 Croatia
# 68     69  Group K                Colombia   0   1                Portugal                Portugal
# 69     70  Group K                DR Congo   2   0              Uzbekistan                DR Congo
# 70     71  Group J                 Algeria   1   0                 Austria                 Algeria
# 71     72  Group J                  Jordan   0   2               Argentina               Argentina

# %% [markdown]
# ---
# ## 2. Group Standings

# %%
# build standings table for all 12 groups from group-stage results
def build_standings(gs_df: pd.DataFrame) -> pd.DataFrame:
    """
    Tiebreakers (when points equal):
      1. Head-to-head points among tied teams
      2. Goal difference (all group games)
      3. Goals scored (all group games)
      4. Elo rating (proxy for FIFA rank)
    """
    stats: dict[str, dict] = {}
    h2h: dict[tuple, int] = {}  # (team_a, team_b) -> pts earned by team_a

    for _, r in gs_df.iterrows():
        h, a = r['home'], r['away']
        hg, ag = int(r['home_goals']), int(r['away_goals'])
        if hg > ag:
            h2h[(h, a)], h2h[(a, h)] = 3, 0
        elif hg == ag:
            h2h[(h, a)], h2h[(a, h)] = 1, 1
        else:
            h2h[(h, a)], h2h[(a, h)] = 0, 3
        for team, gf, ga in [
            (r['home'], r['home_goals'], r['away_goals']),
            (r['away'], r['away_goals'], r['home_goals']),
        ]:
            if team not in stats:
                stats[team] = {'gp': 0, 'w': 0, 'd': 0, 'l': 0, 'gf': 0, 'ga': 0, 'pts': 0}
            s = stats[team]
            s['gp'] += 1
            s['gf'] += gf
            s['ga'] += ga
            if gf > ga:
                s['w']   += 1
                s['pts'] += 3
            elif gf == ga:
                s['d']   += 1
                s['pts'] += 1
            else:
                s['l'] += 1

    rows = []
    for team, s in stats.items():
        rows.append({
            'team':  team,
            'group': name_to_group[team],
            'gp':    s['gp'],
            'w':     s['w'],
            'd':     s['d'],
            'l':     s['l'],
            'gf':    s['gf'],
            'ga':    s['ga'],
            'gd':    s['gf'] - s['ga'],
            'pts':   s['pts'],
            'elo':   get_elo(team),
        })

    df = pd.DataFrame(rows)

    def calc_h2h_pts(team, opponents):
        return sum(h2h.get((team, opp), 0) for opp in opponents)

    ranked = []
    for _, grp in df.groupby('group'):
        grp = grp.sort_values('pts', ascending=False).reset_index(drop=True)
        tiers = []
        for _, tied in grp.groupby('pts', sort=False):
            if len(tied) == 1:
                tiers.append(tied)
            else:
                tied_teams = tied['team'].tolist()
                tied = tied.copy()
                tied['h2h_pts'] = tied['team'].apply(
                    lambda t: calc_h2h_pts(t, [x for x in tied_teams if x != t])
                )
                tied = tied.sort_values(
                    ['h2h_pts', 'gd', 'gf', 'elo'],
                    ascending=[False, False, False, False]
                ).drop(columns='h2h_pts')
                tiers.append(tied)
        ranked.append(pd.concat(tiers))

    df = pd.concat(ranked).reset_index(drop=True)

    # Add rank within group (1-4)
    df['rank'] = df.groupby('group').cumcount() + 1
    return df


standings = build_standings(gs_df)
print(standings[['group','rank','team','gp','w','d','l','gf','ga','gd','pts','elo']].to_string(index=False))
# Out:
# group  rank                   team  gp  w  d  l  gf  ga  gd  pts  elo
#     A     1                 Mexico   3  2  0  1   3   1   2    6 1860
#     A     2            South Korea   3  2  0  1   3   1   2    6 1752
#     A     3                Czechia   3  2  0  1   2   1   1    6 1726
#     A     4           South Africa   3  0  0  3   0   5  -5    0 1524
#     B     1            Switzerland   3  3  0  0   6   0   6    9 1889
#     B     2                 Canada   3  1  1  1   3   3   0    4 1784
#     B     3 Bosnia and Herzegovina   3  1  1  1   3   3   0    4 1594
#     B     4                  Qatar   3  0  0  3   0   6  -6    0 1425
#     C     1                Morocco   3  3  0  0   5   0   5    9 1822
#     C     2                 Brazil   3  2  0  1   4   1   3    6 1984
#     C     3               Scotland   3  1  0  2   2   4  -2    3 1767
#     C     4                  Haiti   3  0  0  3   0   6  -6    0 1532
#     D     1                 Turkey   3  3  0  0   5   0   5    9 1902
#     D     2                    USA   3  2  0  1   4   1   3    6 1721
#     D     3               Paraguay   3  1  0  2   2   4  -2    3 1833
#     D     4              Australia   3  0  0  3   0   6  -6    0 1783
#     E     1                Germany   3  3  0  0   6   0   6    9 1923
#     E     2                Ecuador   3  2  0  1   3   2   1    6 1933
#     E     3          Côte d'Ivoire   3  1  0  2   2   3  -1    3 1676
#     E     4                Curaçao   3  0  0  3   0   6  -6    0 1436
#     F     1            Netherlands   3  3  0  0   6   0   6    9 1961
#     F     2                 Sweden   3  2  0  1   4   2   2    6 1719
#     F     3                  Japan   3  1  0  2   2   4  -2    3 1904
#     F     4                Tunisia   3  0  0  3   0   6  -6    0 1636
#     G     1                Belgium   3  3  0  0   5   0   5    9 1867
#     G     2                  Egypt   3  2  0  1   4   1   3    6 1689
#     G     3                IR Iran   3  1  0  2   2   4  -2    3 1760
#     G     4            New Zealand   3  0  0  3   0   6  -6    0 1585
#     H     1                  Spain   3  3  0  0   6   0   6    9 2165
#     H     2                Uruguay   3  2  0  1   4   2   2    6 1892
#     H     3             Cabo Verde   3  1  0  2   1   4  -3    3 1549
#     H     4           Saudi Arabia   3  0  0  3   0   5  -5    0 1568
#     I     1                 France   3  3  0  0   6   0   6    9 2081
#     I     2                Senegal   3  2  0  1   3   2   1    6 1878
#     I     3                 Norway   3  1  0  2   2   3  -1    3 1912
#     I     4                   Iraq   3  0  0  3   0   6  -6    0 1607
#     J     1              Argentina   3  3  0  0   6   0   6    9 2113
#     J     2                Algeria   3  2  0  1   3   2   1    6 1743
#     J     3                Austria   3  1  0  2   2   3  -1    3 1827
#     J     4                 Jordan   3  0  0  3   0   6  -6    0 1690
#     K     1               Portugal   3  3  0  0   5   0   5    9 1984
#     K     2               Colombia   3  2  0  1   4   1   3    6 1975
#     K     3               DR Congo   3  1  0  2   2   4  -2    3 1655
#     K     4             Uzbekistan   3  0  0  3   0   6  -6    0 1727
#     L     1                England   3  3  0  0   5   0   5    9 2020
#     L     2                Croatia   3  2  0  1   4   2   2    6 1930
#     L     3                  Ghana   3  1  0  2   2   3  -1    3 1503
#     L     4                 Panama   3  0  0  3   0   6  -6    0 1737

# %% [markdown]
# ### Group Standings Summary (Qualification Status)

# %%
def qualify_label(rank: int, team: str, qualified_thirds: set) -> str:
    if rank == 1:
        return '✓ 1st'
    elif rank == 2:
        return '✓ 2nd'
    elif rank == 3:
        return '? 3rd'
    else:
        return '✗ Out'

disp = standings[['group','rank','team','pts','gd','gf','elo']].copy()
disp['status'] = disp['rank'].map({1:'✓ 1st', 2:'✓ 2nd', 3:'→ TBD 3rd', 4:'✗ Eliminated'})
disp.columns = ['Group','Rank','Team','Pts','GD','GF','Elo','Status']
disp
# Out:
#    Group  Rank                    Team  Pts  GD  GF   Elo        Status
# 0      A     1                  Mexico    6   2   3  1860         ✓ 1st
# 1      A     2             South Korea    6   2   3  1752         ✓ 2nd
# 2      A     3                 Czechia    6   1   2  1726     → TBD 3rd
# 3      A     4            South Africa    0  -5   0  1524  ✗ Eliminated
# 4      B     1             Switzerland    9   6   6  1889         ✓ 1st
# 5      B     2                  Canada    4   0   3  1784         ✓ 2nd
# 6      B     3  Bosnia and Herzegovina    4   0   3  1594     → TBD 3rd
# 7      B     4                   Qatar    0  -6   0  1425  ✗ Eliminated
# 8      C     1                 Morocco    9   5   5  1822         ✓ 1st
# 9      C     2                  Brazil    6   3   4  1984         ✓ 2nd
# 10     C     3                Scotland    3  -2   2  1767     → TBD 3rd
# 11     C     4                   Haiti    0  -6   0  1532  ✗ Eliminated
# 12     D     1                  Turkey    9   5   5  1902         ✓ 1st
# 13     D     2                     USA    6   3   4  1721         ✓ 2nd
# 14     D     3                Paraguay    3  -2   2  1833     → TBD 3rd
# 15     D     4               Australia    0  -6   0  1783  ✗ Eliminated
# 16     E     1                 Germany    9   6   6  1923         ✓ 1st
# 17     E     2                 Ecuador    6   1   3  1933         ✓ 2nd
# 18     E     3           Côte d'Ivoire    3  -1   2  1676     → TBD 3rd
# 19     E     4                 Curaçao    0  -6   0  1436  ✗ Eliminated
# 20     F     1             Netherlands    9   6   6  1961         ✓ 1st
# 21     F     2                  Sweden    6   2   4  1719         ✓ 2nd
# 22     F     3                   Japan    3  -2   2  1904     → TBD 3rd
# 23     F     4                 Tunisia    0  -6   0  1636  ✗ Eliminated
# 24     G     1                 Belgium    9   5   5  1867         ✓ 1st
# 25     G     2                   Egypt    6   3   4  1689         ✓ 2nd
# 26     G     3                 IR Iran    3  -2   2  1760     → TBD 3rd
# 27     G     4             New Zealand    0  -6   0  1585  ✗ Eliminated
# 28     H     1                   Spain    9   6   6  2165         ✓ 1st
# 29     H     2                 Uruguay    6   2   4  1892         ✓ 2nd
# 30     H     3              Cabo Verde    3  -3   1  1549     → TBD 3rd
# 31     H     4            Saudi Arabia    0  -5   0  1568  ✗ Eliminated
# 32     I     1                  France    9   6   6  2081         ✓ 1st
# 33     I     2                 Senegal    6   1   3  1878         ✓ 2nd
# 34     I     3                  Norway    3  -1   2  1912     → TBD 3rd
# 35     I     4                    Iraq    0  -6   0  1607  ✗ Eliminated
# 36     J     1               Argentina    9   6   6  2113         ✓ 1st
# 37     J     2                 Algeria    6   1   3  1743         ✓ 2nd
# 38     J     3                 Austria    3  -1   2  1827     → TBD 3rd
# 39     J     4                  Jordan    0  -6   0  1690  ✗ Eliminated
# 40     K     1                Portugal    9   5   5  1984         ✓ 1st
# 41     K     2                Colombia    6   3   4  1975         ✓ 2nd
# 42     K     3                DR Congo    3  -2   2  1655     → TBD 3rd
# 43     K     4              Uzbekistan    0  -6   0  1727  ✗ Eliminated
# 44     L     1                 England    9   5   5  2020         ✓ 1st
# 45     L     2                 Croatia    6   2   4  1930         ✓ 2nd
# 46     L     3                   Ghana    3  -1   2  1503     → TBD 3rd
# 47     L     4                  Panama    0  -6   0  1737  ✗ Eliminated

# %% [markdown]
# ---
# ## 3. Third-Place Team Ranking
#
# All 12 third-place finishers are ranked by: points → GD → GF → Elo.
# The top 8 advance to the Round of 32.

# %%
thirds = standings[standings['rank'] == 3].sort_values(
    ['pts', 'gd', 'gf', 'elo'],
    ascending=[False, False, False, False]
).reset_index(drop=True)

thirds['third_rank'] = range(1, len(thirds) + 1)
thirds['advances'] = thirds['third_rank'] <= 8

print('All third-place teams ranked (top 8 advance):\n')
display_thirds = thirds[['third_rank','group','team','pts','gd','gf','elo','advances']].copy()
display_thirds.columns = ['Rank','Group','Team','Pts','GD','GF','Elo','Advances']
display_thirds
# Out:
# All third-place teams ranked (top 8 advance):
#     Rank Group                    Team  Pts  GD  GF   Elo  Advances
# 0      1     A                 Czechia    6   1   2  1726      True
# 1      2     B  Bosnia and Herzegovina    4   0   3  1594      True
# 2      3     I                  Norway    3  -1   2  1912      True
# 3      4     J                 Austria    3  -1   2  1827      True
# 4      5     E           Côte d'Ivoire    3  -1   2  1676      True
# 5      6     L                   Ghana    3  -1   2  1503      True
# 6      7     F                   Japan    3  -2   2  1904      True
# 7      8     D                Paraguay    3  -2   2  1833      True
# 8      9     C                Scotland    3  -2   2  1767     False
# 9     10     G                 IR Iran    3  -2   2  1760     False
# 10    11     K                DR Congo    3  -2   2  1655     False
# 11    12     H              Cabo Verde    3  -3   1  1549     False

# %% [markdown]
# ---
# ## 4. Third-Place Bracket Allocation
#
# The 8 qualifying group letters are sorted and looked up in FIFA's official 495-row allocation table, which assigns each third-place team to a specific Round of 32 slot.

# %%
# The 8 advancing third-place teams and their groups
qualifying_thirds = thirds[thirds['advances']]
qualifying_groups_letters = sorted(qualifying_thirds['group'].tolist())
combo_key = ''.join(qualifying_groups_letters)

print(f'Qualifying third-place groups: {qualifying_groups_letters}')
print(f'Combination key: {combo_key}')

alloc_row = alloc_df[alloc_df['qualifying_groups'] == combo_key]

if alloc_row.empty:
    raise ValueError(f'No allocation row found for combination: {combo_key}')

alloc_row = alloc_row.iloc[0]

# Map: match_number -> which group's 3rd-place team plays there
third_slot: dict[int, str] = {}
for col in ['match_74', 'match_77', 'match_79', 'match_80', 'match_81', 'match_82', 'match_85', 'match_87']:
    match_num = int(col.split('_')[1])
    group_letter = alloc_row[col].replace('3', '')
    third_slot[match_num] = group_letter

# Build lookup: group letter → team name (for qualifying thirds)
group_to_third_team: dict[str, str] = dict(zip(qualifying_thirds['group'], qualifying_thirds['team']))

# prints the third place match assignments
print('\nThird-place match assignments:')
for match_num, grp in sorted(third_slot.items()):
    team = group_to_third_team.get(grp, f'[Group {grp} 3rd]')
    print(f'  Match {match_num}: 3rd place from Group {grp} → {team}')
# Out:
# Qualifying third-place groups: ['A', 'B', 'D', 'E', 'F', 'I', 'J', 'L']
# Combination key: ABDEFIJL
#
# Third-place match assignments:
#   Match 75: 3rd place from Group D → Paraguay
#   Match 78: 3rd place from Group F → Japan
#   Match 79: 3rd place from Group E → Côte d'Ivoire
#   Match 80: 3rd place from Group I → Norway
#   Match 81: 3rd place from Group A → Czechia
#   Match 82: 3rd place from Group B → Bosnia and Herzegovina
#   Match 85: 3rd place from Group J → Austria
#   Match 88: 3rd place from Group L → Ghana

# %% [markdown]
# ---
# ## 5. Knockout Bracket Simulation
#
# Round of 32 → Round of 16 → Quarterfinals → Semifinals → Bronze Final → Final

# %%
import re

# returns the team that finished in position `rank` in the given group
def get_group_finisher(rank: int, group: str) -> str:
    result = standings[(standings['group'] == group) & (standings['rank'] == rank)]
    if result.empty:
        raise ValueError(f'No rank-{rank} team in group {group}')
    return result.iloc[0]['team']

# resolves a bracket token like '1A' into a concrete team name
def resolve_team(token: str,
                 match_winners: dict[int, str],
                 match_losers: dict[int, str]) -> str:
    # Winner of match N
    m = re.match(r'^W(\d+)$', token)
    if m:
        mn = int(m.group(1))
        return match_winners[mn]

    # Runner-up (loser) of match N
    m = re.match(r'^RU(\d+)$', token)
    if m:
        mn = int(m.group(1))
        return match_losers[mn]

    # Group finisher: '1A', '2F', etc.
    m = re.match(r'^([12])([A-L])$', token)
    if m:
        return get_group_finisher(int(m.group(1)), m.group(2))

    # Third-place slot: '3ABCDF' (match number determines which group's 3rd)
    # The calling code handles this separately via third_slot
    raise ValueError(f'Cannot resolve token: {token}')


def parse_label_tokens(label: str) -> tuple[str, str]:
    """Split a match_label like '1E vs 3ABCDF' into two raw tokens."""
    parts = label.strip().split(' vs ')
    if len(parts) != 2:
        raise ValueError(f'Unexpected label format: {label}')
    return parts[0].strip(), parts[1].strip()


# Run knockout bracket
match_winners: dict[int, str] = {}   # match_number -> winner team name
match_losers:  dict[int, str] = {}   # match_number-> loser team name (for bronze)

ko_matches = matches_df[matches_df['stage_id'] >= 2].sort_values('match_number')

stage_names = {2: 'Round of 32', 3: 'Round of 16', 4: 'Quarterfinals',
               5: 'Semifinals', 6: 'Bronze Final', 7: 'Final'}

ko_results = []

for _, row in ko_matches.iterrows():
    mn    = int(row['match_number'])
    stage = int(row['stage_id'])
    label = row['match_label']

    tok_a, tok_b = parse_label_tokens(label)

    # Resolve third-place tokens (e.g. '3ABCDF') using allocation table
    def resolve_with_third(tok):
        if re.match(r'^3[A-L]+$', tok):
            grp = third_slot[mn]
            return group_to_third_team[grp]
        return resolve_team(tok, match_winners, match_losers)

    team_a = resolve_with_third(tok_a)
    team_b = resolve_with_third(tok_b)

    winner, loser, w_prob, l_prob = predict_knockout_winner(team_a, team_b)
    hg, ag, _ = predict_group_match(team_a, team_b)
    match_winners[mn] = winner
    match_losers[mn]  = loser

    ko_results.append({
        'match':    mn,
        'stage':    stage_names[stage],
        'team_a':   team_a,
        'team_b':   team_b,
        'home_goals': hg,
        'away_goals': ag,
        'winner':   winner,
        'loser':    loser,
        'win_prob': round(w_prob, 3),
        'lose_prob': round(l_prob, 3),
    })

ko_df = pd.DataFrame(ko_results)
print(f'{len(ko_df)} knockout matches resolved')
# Out:
# 32 knockout matches resolved

# %% [markdown]
# ---
# ## 6. Results Output
#
# ### Round of 32

# %%
# show_stage shows the result of every match
def show_stage(stage_name: str):
    df = ko_df[ko_df['stage'] == stage_name][['match','team_a','home_goals','away_goals','team_b','winner','win_prob']].copy()
    df.columns = ['Match', 'Team A', 'HG', 'AG', 'Team B', 'Winner', 'Win Prob']
    return df.reset_index(drop=True)

show_stage('Round of 32')
# Out:
#     Match       Team A                  Team B         Winner  Win Prob
# 0      73  South Korea                  Canada    South Korea     0.817
# 1      74      Morocco                  Sweden        Morocco     0.772
# 2      75      Germany                Paraguay        Germany     0.876
# 3      76  Netherlands                  Brazil         Brazil     0.525
# 4      77      Ecuador                 Senegal        Senegal     0.516
# 5      78       France                   Japan         France     0.825
# 6      79       Mexico           Côte d'Ivoire  Côte d'Ivoire     0.646
# 7      80      England                  Norway        England     0.807
# 8      81      Belgium                 Czechia        Belgium     0.857
# 9      82       Turkey  Bosnia and Herzegovina         Turkey     0.866
# 10     83        Spain                 Algeria          Spain     0.825
# 11     84     Colombia                 Croatia        Croatia     0.576
# 12     85  Switzerland                 Austria    Switzerland     0.535
# 13     86          USA                   Egypt            USA     0.553
# 14     87    Argentina                 Uruguay      Argentina     0.732
# 15     88     Portugal                   Ghana       Portugal     0.825

# %% [markdown]
# ### Round of 16

# %%
show_stage('Round of 16')
# Out:
#    Match         Team A     Team B     Winner  Win Prob
# 0     89    South Korea    Germany    Germany     0.552
# 1     90        Morocco    Senegal    Morocco     0.626
# 2     91         Brazil     France     France     0.606
# 3     92  Côte d'Ivoire    England    England     0.706
# 4     93          Spain    Croatia      Spain     0.783
# 5     94        Belgium     Turkey    Belgium     0.610
# 6     95            USA   Portugal   Portugal     0.757
# 7     96    Switzerland  Argentina  Argentina     0.773

# %% [markdown]
# ### Quarterfinals

# %%
show_stage('Quarterfinals')
# Out:
#    Match    Team A     Team B    Winner  Win Prob
# 0     97   Germany    Morocco   Morocco     0.584
# 1     98     Spain    Belgium     Spain     0.715
# 2     99    France    England    France     0.532
# 3    100  Portugal  Argentina  Portugal     0.576

# %% [markdown]
# ### Semifinals

# %%
show_stage('Semifinals')
# Out:
#    Match   Team A    Team B  Winner  Win Prob
# 0    101  Morocco     Spain   Spain     0.554
# 1    102   France  Portugal  France     0.707

# %% [markdown]
# ### Bronze Final (3rd Place)

# %%
show_stage('Bronze Final')
# Out:
#    Match   Team A    Team B    Winner  Win Prob
# 0    103  Morocco  Portugal  Portugal     0.644

# %% [markdown]
# ---
# ## 🏆 Final

# %%
final_row = ko_df[ko_df['stage'] == 'Final'].iloc[0]
champion  = final_row['winner']
runner_up = final_row['loser']

print('=' * 60)
print(f'  FINAL  (Match {final_row["match"]})')
print(f'  {final_row["team_a"]:25s} {final_row["home_goals"]}-{final_row["away_goals"]}  vs  {final_row["team_b"]}')
print(f'  Winner:     {champion}')
print(f'  Runner-up:  {runner_up}')
print('=' * 60)
print(f'\n  2026 FIFA WORLD CUP CHAMPION: {champion.upper()}')
print(f'  (Elo: {get_elo(champion):.0f} | Win prob in final: {final_row["win_prob"]:.1%})')
# Out:
# ============================================================
#   FINAL  (Match 104)
#   Spain                     vs  France
#   Winner:     France
#   Runner-up:  Spain
# ============================================================
#
#   2026 FIFA WORLD CUP CHAMPION: FRANCE
#   (Elo: 2081 | Win prob in final: 52.9%)

# %% [markdown]
# ---
# ## Full Knockout Bracket Summary

# %%
for stage in ['Round of 32', 'Round of 16', 'Quarterfinals', 'Semifinals', 'Bronze Final', 'Final']:
    subset = ko_df[ko_df['stage'] == stage]
    print(f'\n{stage.upper()}')
    print('-' * 60)
    for _, r in subset.iterrows():
        print(f'  Match {r["match"]:3d}: {r["team_a"]:26s} {r["home_goals"]}-{r["away_goals"]} {r["team_b"]:26s}  →  {r["winner"]}')
# Out:
# ROUND OF 32
# ------------------------------------------------------------
#   Match  73: South Korea                vs Canada                      →  South Korea
#   Match  74: Morocco                    vs Sweden                      →  Morocco
#   Match  75: Germany                    vs Paraguay                    →  Germany
#   Match  76: Netherlands                vs Brazil                      →  Brazil
#   Match  77: Ecuador                    vs Senegal                     →  Senegal
#   Match  78: France                     vs Japan                       →  France
#   Match  79: Mexico                     vs Côte d'Ivoire               →  Côte d'Ivoire
#   Match  80: England                    vs Norway                      →  England
#   Match  81: Belgium                    vs Czechia                     →  Belgium
#   Match  82: Turkey                     vs Bosnia and Herzegovina      →  Turkey
#   Match  83: Spain                      vs Algeria                     →  Spain
#   Match  84: Colombia                   vs Croatia                     →  Croatia
#   Match  85: Switzerland                vs Austria                     →  Switzerland
#   Match  86: USA                        vs Egypt                       →  USA
#   Match  87: Argentina                  vs Uruguay                     →  Argentina
#   Match  88: Portugal                   vs Ghana                       →  Portugal
#
# ROUND OF 16
# ------------------------------------------------------------
#   Match  89: South Korea                vs Germany                     →  Germany
#   Match  90: Morocco                    vs Senegal                     →  Morocco
#   Match  91: Brazil                     vs France                      →  France
#   Match  92: Côte d'Ivoire              vs England                     →  England
#   Match  93: Spain                      vs Croatia                     →  Spain
#   Match  94: Belgium                    vs Turkey                      →  Belgium
#   Match  95: USA                        vs Portugal                    →  Portugal
#   Match  96: Switzerland                vs Argentina                   →  Argentina
#
# QUARTERFINALS
# ------------------------------------------------------------
#   Match  97: Germany                    vs Morocco                     →  Morocco
#   Match  98: Spain                      vs Belgium                     →  Spain
#   Match  99: France                     vs England                     →  France
#   Match 100: Portugal                   vs Argentina                   →  Portugal
#
# SEMIFINALS
# ------------------------------------------------------------
#   Match 101: Morocco                    vs Spain                       →  Spain
#   Match 102: France                     vs Portugal                    →  France
#
# BRONZE FINAL
# ------------------------------------------------------------
#   Match 103: Morocco                    vs Portugal                    →  Portugal
#
# FINAL
# ------------------------------------------------------------
#   Match 104: Spain                      vs France                      →  France
